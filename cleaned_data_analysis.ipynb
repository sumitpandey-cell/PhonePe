# %%
import pandas as pd

# %%
agg_txn = pd.read_csv('data/cleaned_data/agg_txn.csv')
agg_user = pd.read_csv('data/cleaned_data/agg_user.csv')
map_txn = pd.read_csv('data/cleaned_data/map_txn.csv')
map_user = pd.read_csv('data/cleaned_data/map_user.csv')
top_txn_dis = pd.read_csv('data/cleaned_data/top_txn_dis.csv')
top_txn_pin = pd.read_csv('data/cleaned_data/top_txn_pin.csv')
top_user_dis = pd.read_csv('data/cleaned_data/top_user_dis.csv')
top_user_pin = pd.read_csv('data/cleaned_data/top_user_pin.csv')

# %%
# Print all columns of each DataFrame using a loop
dataframes = [agg_txn,map_txn,top_txn_dis, top_txn_pin]
for df in dataframes:
    print(df.columns)
# Out:
# Index(['State', 'Year', 'Quarter', 'Transaction_type', 'Transaction_count',
#        'Total_amount'],
#       dtype='str')
# Index(['State', 'Year', 'Quarter', 'District', 'Transaction_count',
#        'Total_amount'],
#       dtype='str')
# Index(['State', 'Year', 'Quarter', 'District', 'Transaction_count',
#        'Total_amount'],
#       dtype='str')
# Index(['State', 'Year', 'Quarter', 'Pincode', 'Transaction_count',
#        'Total_amount'],
#       dtype='str')

# %%
agg_txn[agg_txn['State'] == 'delhi']["Transaction_count"].sum()
# Out:
# np.int64(8495316647)

# %%
map_txn[map_txn['State'] == 'delhi']["Transaction_count"].sum()
# Out:
# np.int64(8495316647)

# %%
top_txn_dis[(top_txn_dis['State'] == 'delhi') & (top_txn_dis['Quarter'] == 1) & (top_txn_dis['Year'] == 2018)]["Transaction_count"].sum()
# Out:
# np.int64(6942594)

# %%
top_txn_pin[(top_txn_pin['State'] == 'delhi') & (top_txn_pin['Quarter'] == 1) & (top_txn_pin['Year'] == 2018)]["Transaction_count"].sum()
# Out:
# np.int64(4127772)

# %%
map_txn.head()
# Out:
#                        State  Year  Quarter  \
# 0  andaman-&-nicobar-islands  2018        1
# 1  andaman-&-nicobar-islands  2018        1
# 2  andaman-&-nicobar-islands  2018        1
# 3  andaman-&-nicobar-islands  2018        2
# 4  andaman-&-nicobar-islands  2018        2
#
#                             District  Transaction_count  Total_amount
# 0  north_and_middle_andaman_district                442  9.316631e+05
# 1             south_andaman_district               5688  1.256025e+07
# 2                  nicobars_district                528  1.139849e+06
# 3  north_and_middle_andaman_district                825  1.317863e+06
# 4             south_andaman_district               9395  2.394824e+07
